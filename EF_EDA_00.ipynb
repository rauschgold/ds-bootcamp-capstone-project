# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt

from matplotlib.ticker import PercentFormatter
import seaborn as sns

# %%
#import the data from a csv-file
# World Bank Projects, data as of 08/26/2024 22:00:01 EST
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   World Bank Projects, data as of 08/26/2024 22:00:01 EST
# 0                                         Project ID       \
# 1                                                 id
# 2                                            P507340
# 3                                            P507322
# 4                                            P507318
#
#                     Unnamed: 1                     Unnamed: 2
# 0                       Region                        Country  \
# 1                   regionname                    countryname
# 2                   South Asia              Republic of India
# 3  Latin America and Caribbean  Federative Republic of Brazil
# 4  Eastern and Southern Africa           Republic of Zimbabwe
#
#              Unnamed: 3               Unnamed: 4
# 0        Project Status  Last Stage Reached Name  \
# 1  projectstatusdisplay  last_stage_reached_name
# 2              Pipeline                      NaN
# 3              Pipeline                      NaN
# 4              Pipeline                      NaN
#
#                                           Unnamed: 5
# 0                                       Project Name  \
# 1                                       project_name
# 2  Himachal Disaster Recovery and Resilience Project
# 3                                         Brazil DPF
# 4                                               ZEAP
#
#                        Unnamed: 6           Unnamed: 7
# 0  Project Development Objective   Implementing Agency  \
# 1                             pdo            impagency
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN
#
#                      Unnamed: 8
# 0  Consultant Services Required  \
# 1            cons_serv_reqd_ind
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                                           Unnamed: 9  ...   Unnamed: 17
# 0                                        Project URL  ...  Grant Amount  \
# 1                                                url  ...      grantamt
# 2  http://projects.worldbank.org/P507340/null?lan...  ...           NaN
# 3  http://projects.worldbank.org/P507322/null?lan...  ...           NaN
# 4  http://projects.worldbank.org/P507318/null?lan...  ...           NaN
#
#   Unnamed: 18                   Unnamed: 19
# 0    Borrower            Lending Instrument  \
# 1    borrower                  lendinginstr
# 2         NaN  Investment Project Financing
# 3         NaN    Development Policy Lending
# 4         NaN  Investment Project Financing
#
#                          Unnamed: 20                    Unnamed: 21
# 0  Environmental Assessment Category  Environmental and Social Risk  \
# 1           envassesmentcategorycode            esrc_ovrl_risk_rate
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0    Sector 1    Sector 2    Sector 3     Theme 1     Theme 2
# 1     sector1     sector2     sector3      theme1      theme2
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 27 columns]
